# %%
import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score, recall_score, precision_score
from sklearn.metrics import f1_score, make_scorer
from sklearn.model_selection import cross_validate, StratifiedKFold, train_test_split

from sklearn.svm import SVC
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# X = np.load('drive/MyDrive/DATA/data_1/X.npy').astype(np.int8)
# y = np.load('drive/MyDrive/DATA/data_1/y.npy').astype(np.int8)

# %%
X = np.load('drive/MyDrive/DATA/data_2/X.npy').astype(np.int8)
y = np.load('drive/MyDrive/DATA/data_2/y.npy').astype(np.int8)

# %%
y = np.where(y == 1, 0, 1)
np.unique(y)
# Out:
# array([0, 1])

# %%
X.shape, y.shape
# Out:
# ((1228, 67925), (1228,))

# %%
len(y[y == 1]), len(y[y == 1]) / len(y)
# Out:
# (923, 0.751628664495114)

# %%
model_names = []
for model in [DummyClassifier, LogisticRegression, SVC,
              DecisionTreeClassifier, RandomForestClassifier,
              KNeighborsClassifier, XGBClassifier]:
    model_names.append(model.__name__)

model_names
# Out:
# ['DummyClassifier',
#  'LogisticRegression',
#  'SVC',
#  'DecisionTreeClassifier',
#  'RandomForestClassifier',
#  'KNeighborsClassifier',
#  'XGBClassifier']

# %%
scoring = {'accuracy': 'accuracy',
           'precision': 'precision',
           'recall': 'recall',
           'F1-score': 'f1',
           'recall -': make_scorer(recall_score, pos_label=0),
           'precision -': make_scorer(precision_score, pos_label=0, zero_division=0),
           }

scores_df = pd.DataFrame(index=model_names, columns=list(scoring.keys()))

# %%
clf = DummyClassifier()
scores = cross_validate(clf, X, y, cv=5, scoring=scoring, n_jobs=-1)
mean_scores = pd.DataFrame(scores).apply(np.mean)

# %%
scores_df.loc[type(clf).__name__] = mean_scores.values[2:]
scores_df
# Out:
#                         accuracy precision  ...  recall - precision -
# DummyClassifier         0.635182  0.755443  ...  0.255738     0.26358
# LogisticRegression           NaN       NaN  ...       NaN         NaN
# SVC                          NaN       NaN  ...       NaN         NaN
# DecisionTreeClassifier       NaN       NaN  ...       NaN         NaN
# RandomForestClassifier       NaN       NaN  ...       NaN         NaN
# KNeighborsClassifier         NaN       NaN  ...       NaN         NaN
# XGBClassifier                NaN       NaN  ...       NaN         NaN
#
# [7 rows x 6 columns]

# %%
clf = LogisticRegression(solver='liblinear', penalty='l1', class_weight='balanced')
scores = cross_validate(clf, X, y, cv=5, scoring=scoring)
mean_scores = pd.DataFrame(scores).apply(np.mean)
mean_scores
# Out:
# fit_time            4.666138
# score_time          0.048508
# test_accuracy       0.702778
# test_precision      0.764414
# test_recall         0.874371
# test_F1-score       0.815481
# test_recall -       0.183607
# test_precision -    0.321612
# dtype: float64

# %%
scores_df.loc[type(clf).__name__] = mean_scores.values[2:]
scores_df
# Out:
#                         accuracy precision  ...  recall - precision -
# DummyClassifier         0.635182  0.755443  ...  0.255738     0.26358
# LogisticRegression      0.702778  0.764414  ...  0.183607    0.321612
# SVC                          NaN       NaN  ...       NaN         NaN
# DecisionTreeClassifier       NaN       NaN  ...       NaN         NaN
# RandomForestClassifier       NaN       NaN  ...       NaN         NaN
# KNeighborsClassifier         NaN       NaN  ...       NaN         NaN
# XGBClassifier                NaN       NaN  ...       NaN         NaN
#
# [7 rows x 6 columns]

# %%
clf = DecisionTreeClassifier(class_weight='balanced')
scores = cross_validate(clf, X, y, cv=5, scoring=scoring, n_jobs=-1)
mean_scores = pd.DataFrame(scores).apply(np.mean)
mean_scores
# Out:
# fit_time            19.235872
# score_time           0.038547
# test_accuracy        0.642535
# test_precision       0.763299
# test_recall          0.760652
# test_F1-score        0.761256
# test_recall -        0.285246
# test_precision -     0.282338
# dtype: float64

# %%
scores_df.loc[type(clf).__name__] = mean_scores.values[2:]
scores_df
# Out:
#                         accuracy precision  ...  recall - precision -
# DummyClassifier         0.635182  0.755443  ...  0.255738     0.26358
# LogisticRegression      0.702778  0.764414  ...  0.183607    0.321612
# SVC                          NaN       NaN  ...       NaN         NaN
# DecisionTreeClassifier  0.642535  0.763299  ...  0.285246    0.282338
# RandomForestClassifier       NaN       NaN  ...       NaN         NaN
# KNeighborsClassifier         NaN       NaN  ...       NaN         NaN
# XGBClassifier                NaN       NaN  ...       NaN         NaN
#
# [7 rows x 6 columns]

# %%
clf = RandomForestClassifier(class_weight='balanced')
scores = cross_validate(clf, X, y, cv=5, scoring=scoring, n_jobs=-1)
mean_scores = pd.DataFrame(scores).apply(np.mean)
mean_scores
# Out:
# fit_time            5.483033
# score_time          0.064686
# test_accuracy       0.751628
# test_precision      0.751628
# test_recall         1.000000
# test_F1-score       0.858205
# test_recall -       0.000000
# test_precision -    0.000000
# dtype: float64

# %%
scores_df.loc[type(clf).__name__] = mean_scores.values[2:]
scores_df
# Out:
#                         accuracy precision  ...  recall - precision -
# DummyClassifier         0.635182  0.755443  ...  0.255738     0.26358
# LogisticRegression      0.702778  0.764414  ...  0.183607    0.321612
# SVC                          NaN       NaN  ...       NaN         NaN
# DecisionTreeClassifier  0.642535  0.763299  ...  0.285246    0.282338
# RandomForestClassifier  0.751628  0.751628  ...         0           0
# KNeighborsClassifier         NaN       NaN  ...       NaN         NaN
# XGBClassifier                NaN       NaN  ...       NaN         NaN
#
# [7 rows x 6 columns]

# %%
clf = KNeighborsClassifier(weights='distance', p=1)
scores = cross_validate(clf, X, y, cv=5, scoring=scoring, n_jobs=-1)
mean_scores = pd.DataFrame(scores).apply(np.mean)
mean_scores
# Out:
# /usr/local/lib/python3.7/dist-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# fit_time             8.846984
# score_time          49.978125
# test_accuracy        0.702014
# test_precision       0.751402
# test_recall          0.901475
# test_F1-score        0.819552
# test_recall -        0.098361
# test_precision -     0.261227
# dtype: float64

# %%
scores_df.loc[type(clf).__name__] = mean_scores.values[2:]
scores_df
# Out:
#                         accuracy precision  ...   recall - precision -
# DummyClassifier         0.635182  0.755443  ...   0.255738     0.26358
# LogisticRegression      0.702778  0.764414  ...   0.183607    0.321612
# SVC                          NaN       NaN  ...        NaN         NaN
# DecisionTreeClassifier  0.642535  0.763299  ...   0.285246    0.282338
# RandomForestClassifier  0.751628  0.751628  ...          0           0
# KNeighborsClassifier    0.702014  0.751402  ...  0.0983607    0.261227
# XGBClassifier                NaN       NaN  ...        NaN         NaN
#
# [7 rows x 6 columns]

# %%
clf = XGBClassifier(n_estimators=150,
                    max_depth=3, # 1 - 5 (2-3)
                    # min_child_weight=30, # (? - 30) (30)
                    scale_pos_weight=0.3, # 0.2 - 0.5 (0.3)
                    learning_rate=0.1,
                    # tree_method='gpu_hist',
                    # predictor='gpu_predictor',
                    n_jobs=-1,
                    use_label_encoder=False)


scores = {'accuracy': [],
          'precision': [],
          'recall': [],
          'F1-score': [],
          'recall -': [],
          'precision -': [],
          }



X_train, X_val, y_train, y_val = train_test_split(X, y,
                                                  test_size=0.2,
                                                  shuffle=True,
                                                  stratify=y,
                                                  random_state=42)

clf.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_val, y_val)],
        eval_metric='error',
        early_stopping_rounds=45,
        verbose=True)

print('___')

y_pred = clf.predict(X_val, ntree_limit=clf.best_ntree_limit)

scores['accuracy'].append(accuracy_score(y_val, y_pred))
scores['precision'].append(precision_score(y_val, y_pred))
scores['recall'].append(recall_score(y_val, y_pred))
scores['F1-score'].append(f1_score(y_val, y_pred))
scores['recall -'].append(recall_score(y_val, y_pred, pos_label=0))
scores['precision -'].append(precision_score(y_val, y_pred, pos_label=0, zero_division=0))

scores
# Out:
# [0]	validation_0-error:0.373727	validation_1-error:0.52439
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 25 rounds.
# [1]	validation_0-error:0.310591	validation_1-error:0.443089
# [2]	validation_0-error:0.280041	validation_1-error:0.5
# [3]	validation_0-error:0.307536	validation_1-error:0.512195
# [4]	validation_0-error:0.271894	validation_1-error:0.455285
# [5]	validation_0-error:0.255601	validation_1-error:0.48374
# [6]	validation_0-error:0.213849	validation_1-error:0.49187
# [7]	validation_0-error:0.218941	validation_1-error:0.504065
# [8]	validation_0-error:0.211813	validation_1-error:0.471545
# [9]	validation_0-error:0.186354	validation_1-error:0.471545
# [10]	validation_0-error:0.180244	validation_1-error:0.471545
# [11]	validation_0-error:0.170061	validation_1-error:0.479675
# [12]	validation_0-error:0.155804	validation_1-error:0.463415
# [13]	validation_0-error:0.150713	validation_1-error:0.46748
# [14]	validation_0-error:0.148676	validation_1-error:0.487805
# [15]	validation_0-error:0.142566	validation_1-error:0.46748
# [16]	validation_0-error:0.135438	validation_1-error:0.48374
# [17]	validation_0-error:0.138493	validation_1-error:0.46748
# [18]	validation_0-error:0.119145	validation_1-error:0.451219
# [19]	validation_0-error:0.108961	validation_1-error:0.463415
# [20]	validation_0-error:0.095723	validation_1-error:0.47561
# [21]	validation_0-error:0.089613	validation_1-error:0.430894
# [22]	validation_0-error:0.087576	validation_1-error:0.434959
# [23]	validation_0-error:0.07943	validation_1-error:0.430894
# [24]	validation_0-error:0.069246	validation_1-error:0.418699
# [25]	validation_0-error:0.065173	validation_1-error:0.422764
# [26]	validation_0-error:0.068228	validation_1-error:0.414634
# [27]	validation_0-error:0.057026	validation_1-error:0.402439
# [28]	validation_0-error:0.053971	validation_1-error:0.410569
# [29]	validation_0-error:0.052953	validation_1-error:0.390244
# [30]	validation_0-error:0.04277	validation_1-error:0.398374
# [31]	validation_0-error:0.045825	validation_1-error:0.402439
# [32]	validation_0-error:0.046843	validation_1-error:0.410569
# [33]	validation_0-error:0.037678	validation_1-error:0.414634
# [34]	validation_0-error:0.034623	validation_1-error:0.410569
# [35]	validation_0-error:0.033605	validation_1-error:0.410569
# [36]	validation_0-error:0.03055	validation_1-error:0.398374
# [37]	validation_0-error:0.027495	validation_1-error:0.402439
# [38]	validation_0-error:0.025458	validation_1-error:0.398374
# [39]	validation_0-error:0.029532	validation_1-error:0.406504
# [40]	validation_0-error:0.025458	validation_1-error:0.398374
# [41]	validation_0-error:0.027495	validation_1-error:0.386179
# [42]	validation_0-error:0.025458	validation_1-error:0.394309
# [43]	validation_0-error:0.023422	validation_1-error:0.390244
# [44]	validation_0-error:0.01833	validation_1-error:0.390244
# [45]	validation_0-error:0.017312	validation_1-error:0.386179
# [46]	validation_0-error:0.017312	validation_1-error:0.382114
# [47]	validation_0-error:0.01222	validation_1-error:0.373984
# [48]	validation_0-error:0.015275	validation_1-error:0.357724
# [49]	validation_0-error:0.013238	validation_1-error:0.353659
# [50]	validation_0-error:0.014257	validation_1-error:0.357724
# [51]	validation_0-error:0.016293	validation_1-error:0.369919
# [52]	validation_0-error:0.015275	validation_1-error:0.365854
# [53]	validation_0-error:0.01222	validation_1-error:0.369919
# [54]	validation_0-error:0.011202	validation_1-error:0.353659
# [55]	validation_0-error:0.010183	validation_1-error:0.361789
# [56]	validation_0-error:0.010183	validation_1-error:0.361789
# [57]	validation_0-error:0.009165	validation_1-error:0.361789
# [58]	validation_0-error:0.010183	validation_1-error:0.361789
# [59]	validation_0-error:0.009165	validation_1-error:0.361789
# [60]	validation_0-error:0.010183	validation_1-error:0.361789
# [61]	validation_0-error:0.007128	validation_1-error:0.361789
# [62]	validation_0-error:0.007128	validation_1-error:0.361789
# [63]	validation_0-error:0.00611	validation_1-error:0.357724
# [64]	validation_0-error:0.00611	validation_1-error:0.341463
# [65]	validation_0-error:0.004073	validation_1-error:0.337398
# [66]	validation_0-error:0.002037	validation_1-error:0.341463
# [67]	validation_0-error:0.003055	validation_1-error:0.341463
# [68]	validation_0-error:0.003055	validation_1-error:0.325203
# [69]	validation_0-error:0.003055	validation_1-error:0.341463
# [70]	validation_0-error:0.002037	validation_1-error:0.341463
# [71]	validation_0-error:0.001018	validation_1-error:0.333333
# [72]	validation_0-error:0.001018	validation_1-error:0.329268
# [73]	validation_0-error:0	validation_1-error:0.337398
# [74]	validation_0-error:0	validation_1-error:0.341463
# [75]	validation_0-error:0	validation_1-error:0.345528
# [76]	validation_0-error:0.001018	validation_1-error:0.353659
# [77]	validation_0-error:0.001018	validation_1-error:0.349593
# [78]	validation_0-error:0.001018	validation_1-error:0.345528
# [79]	validation_0-error:0.001018	validation_1-error:0.341463
# [80]	validation_0-error:0.001018	validation_1-error:0.349593
# [81]	validation_0-error:0.001018	validation_1-error:0.353659
# [82]	validation_0-error:0.001018	validation_1-error:0.353659
# [83]	validation_0-error:0	validation_1-error:0.353659
# [84]	validation_0-error:0	validation_1-error:0.353659
# [85]	validation_0-error:0	validation_1-error:0.345528
# [86]	validation_0-error:0	validation_1-error:0.349593
# [87]	validation_0-error:0	validation_1-error:0.345528
# [88]	validation_0-error:0	validation_1-error:0.345528
# [89]	validation_0-error:0	validation_1-error:0.345528
# [90]	validation_0-error:0	validation_1-error:0.353659
# [91]	validation_0-error:0	validation_1-error:0.349593
# [92]	validation_0-error:0	validation_1-error:0.357724
# [93]	validation_0-error:0	validation_1-error:0.353659
# Stopping. Best iteration:
# [68]	validation_0-error:0.003055	validation_1-error:0.325203
#
# ___
# [0]	validation_0-error:0.42057	validation_1-error:0.54065
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 25 rounds.
# [1]	validation_0-error:0.312627	validation_1-error:0.51626
# [2]	validation_0-error:0.281059	validation_1-error:0.48374
# [3]	validation_0-error:0.266802	validation_1-error:0.471545
# [4]	validation_0-error:0.248473	validation_1-error:0.479675
# [5]	validation_0-error:0.228106	validation_1-error:0.471545
# [6]	validation_0-error:0.212831	validation_1-error:0.463415
# [7]	validation_0-error:0.177189	validation_1-error:0.455285
# [8]	validation_0-error:0.167006	validation_1-error:0.406504
# [9]	validation_0-error:0.154786	validation_1-error:0.418699
# [10]	validation_0-error:0.129328	validation_1-error:0.443089
# [11]	validation_0-error:0.133401	validation_1-error:0.439024
# [12]	validation_0-error:0.125255	validation_1-error:0.410569
# [13]	validation_0-error:0.10998	validation_1-error:0.414634
# [14]	validation_0-error:0.10387	validation_1-error:0.410569
# [15]	validation_0-error:0.090631	validation_1-error:0.406504
# [16]	validation_0-error:0.086558	validation_1-error:0.414634
# [17]	validation_0-error:0.082485	validation_1-error:0.386179
# [18]	validation_0-error:0.072301	validation_1-error:0.378049
# [19]	validation_0-error:0.072301	validation_1-error:0.390244
# [20]	validation_0-error:0.063136	validation_1-error:0.390244
# [21]	validation_0-error:0.062118	validation_1-error:0.369919
# [22]	validation_0-error:0.065173	validation_1-error:0.361789
# [23]	validation_0-error:0.058045	validation_1-error:0.369919
# [24]	validation_0-error:0.053971	validation_1-error:0.357724
# [25]	validation_0-error:0.05499	validation_1-error:0.369919
# [26]	validation_0-error:0.051935	validation_1-error:0.349593
# [27]	validation_0-error:0.04888	validation_1-error:0.357724
# [28]	validation_0-error:0.046843	validation_1-error:0.365854
# [29]	validation_0-error:0.038697	validation_1-error:0.369919
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-0849799f4c75> in <module>()
#      25             eval_metric='error',
#      26             early_stopping_rounds=25,
# ---> 27             verbose=True)
#      28
#      29     print('___')
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     730                               evals_result=evals_result, obj=obj, feval=feval,
#     731                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 732                               callbacks=callbacks)
#     733
#     734         self.objective = xgb_options["objective"]
#
# /usr/local/lib/python3.7/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.7/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
scores_df.loc[type(clf).__name__] = pd.DataFrame(scores).values
scores_df
# Out:
#                         accuracy precision  ...   recall - precision -
# DummyClassifier         0.635182  0.755443  ...   0.255738     0.26358
# LogisticRegression      0.702778  0.764414  ...   0.183607    0.321612
# SVC                     0.751628  0.751628  ...          0           0
# DecisionTreeClassifier  0.642535  0.763299  ...   0.285246    0.282338
# RandomForestClassifier  0.751628  0.751628  ...          0           0
# KNeighborsClassifier    0.702014  0.751402  ...  0.0983607    0.261227
# XGBClassifier           0.674797  0.751196  ...   0.147541    0.243243
#
# [7 rows x 6 columns]

# %%
mean_scores = pd.DataFrame(scores).apply(np.mean)
mean_scores

# %%
# scores_df.loc[type(clf).__name__] = mean_scores.values
# scores_df

# %%
clf = SVC()
scores = cross_validate(clf, X, y, cv=5, scoring=scoring, n_jobs=-1)
mean_scores = pd.DataFrame(scores).apply(np.mean)
mean_scores
# Out:
# /usr/local/lib/python3.7/dist-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# fit_time            122.383586
# score_time           30.417684
# test_accuracy         0.751628
# test_precision        0.751628
# test_recall           1.000000
# test_F1-score         0.858205
# test_recall -         0.000000
# test_precision -      0.000000
# dtype: float64

# %%
mean_scores = pd.DataFrame(scores).apply(np.mean)
mean_scores
# Out:
# fit_time            122.383586
# score_time           30.417684
# test_accuracy         0.751628
# test_precision        0.751628
# test_recall           1.000000
# test_F1-score         0.858205
# test_recall -         0.000000
# test_precision -      0.000000
# dtype: float64

# %%
scores_df.loc[type(clf).__name__] = mean_scores.values[2:]
scores_df
# Out:
#                         accuracy precision  ...   recall - precision -
# DummyClassifier         0.635182  0.755443  ...   0.255738     0.26358
# LogisticRegression      0.702778  0.764414  ...   0.183607    0.321612
# SVC                     0.751628  0.751628  ...          0           0
# DecisionTreeClassifier  0.642535  0.763299  ...   0.285246    0.282338
# RandomForestClassifier  0.751628  0.751628  ...          0           0
# KNeighborsClassifier    0.702014  0.751402  ...  0.0983607    0.261227
# XGBClassifier           0.580601  0.760491  ...   0.396721    0.277471
#
# [7 rows x 6 columns]
